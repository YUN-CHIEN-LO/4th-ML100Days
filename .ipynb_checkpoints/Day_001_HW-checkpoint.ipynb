# %% [markdown]
# # Day_001_HW

# %% [markdown]
# ### 羅云謙

# %% [markdown]
# ## 01. 請寫一個函式用來計算 Mean Square Error

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt
import math
from sklearn.metrics import mean_squared_error

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
#     """
#     請完成這個 Function 後往下執行
#     mse = sum i=1~n(yi-ypi)^2 / n
#     """
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
cor = mean_squared_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
# print("Correct Mean squared error is %.3f" % (cor))
print("The Mean absolute error is %.3f" % (MAE))
if(cor == MSE):
    print("Correct MSE")
# Out:
# The Mean squared error is 226.819
# The Mean absolute error is 11.717
# Correct MSE

# %% [markdown]
# ## 作業2

# %% [markdown]
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# *****
# ## Coronavirus-Dataset
# ##### Official information of Coronavirus disease 2019 (COVID-19) in South Korea
#
# *****
#
# #### 1. 你選的這組資料為何重要
# 這組資料很重要，因為它包含了韓國國內武漢肺炎病患的基本資料、診斷時間和傳染途徑，分析這組資料有助於掌控疫情發展以及實施防疫措施。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# KCDC (Korea Centers for Disease Control & Prevention) announces official information of COVID-19 everyday.
# We make a structured data set based on the report materials of KCDC official website.
#
# #### 3. 蒐集而來的資料型態為何
#
# 3個csv file包含病患的基本資料、診斷時間和傳染途徑
#
# #### 4. 這組資料想解決的問題如何評估
# 掌控疫情發展以及實施防疫措施

# %% [markdown]
# ## 作業3

# %% [markdown]
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 希望在對的時間派出合適的車隊數量，到合適的地方，避免浪費時間與人力資源。
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 哪些地點、時間叫車輛比較多，上下班、例假日時段，客群分佈...
# 可以以每一輛車為單位搜集基料加以分析
# #### 3. 蒐集而來的資料型態為何
# 結構化的表格
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 預測哪些時間與地點的組合，載客需求量會大
